# %%
# Importando as bibliotecas

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Upload do dataset

df_customer = pd.read_csv('olist_customers_dataset.csv')
df_payment = pd.read_csv('olist_order_payments_dataset.csv')
df_categ = pd.read_csv('product_category_name_translation.csv')
df_produt = pd.read_csv('olist_products_dataset.csv')
df_order = pd.read_csv('olist_orders_dataset.csv')
df_item = pd.read_csv('olist_order_items_dataset.csv')
df_customer.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
df_customer.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
df_pe = df_customer.loc[df_customer['customer_state'] == 'PE'].reset_index()
df_camocim = df_customer.loc[df_customer['customer_city'] == 'camocim de sao felix'].reset_index()
df_camocim.head()
# Out:
#    index                       customer_id                customer_unique_id  \
# 0   3651  24438521febd6fffbfe369c24f3fae11  bd7491d137efc5fafb7a295bb2d238f7
# 1  66779  1fd5eaabb77d2652f4eda8149dac021a  8b42400c4cb61d91fbc68a94467a700a
#
#    customer_zip_code_prefix         customer_city customer_state
# 0                     55665  camocim de sao felix             PE
# 1                     55665  camocim de sao felix             PE

# %%
# df_pe['customer_city'].value_counts()

# %%
df_customer.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
df_group = df_customer.drop(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix'], axis = 1).groupby('customer_state')['customer_city'].value_counts()
df_group.head(5)
# Out:
# customer_state  customer_city
# AC              rio branco          70
#                 cruzeiro do sul      3
#                 senador guiomard     2
#                 xapuri               2
#                 epitaciolandia       1
# Name: count, dtype: int64

# %%
df_categ.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
df_produt.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_payment_camocim = df_payment.loc[df_payment['order_id'] == '083606af9191f3c3119ed90e616df1ca']
df_payment_camocim.head()
# Out:
#                                 order_id  payment_sequential payment_type  \
# 103133  083606af9191f3c3119ed90e616df1ca                   1  credit_card
#
#         payment_installments  payment_value
# 103133                     1         383.32

# %%
df_order.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df_order_camocim = df_order.loc[df_order['customer_id'] == '24438521febd6fffbfe369c24f3fae11']
df_order_camocim.head()
# Out:
#                                order_id                       customer_id  \
# 62412  083606af9191f3c3119ed90e616df1ca  24438521febd6fffbfe369c24f3fae11
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 62412    delivered      2017-09-05 11:59:59  2017-09-05 12:15:48
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 62412          2017-09-08 19:27:54           2017-09-18 17:58:59
#
#       order_estimated_delivery_date
# 62412           2017-10-04 00:00:00

# %%
df_item.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_item_camocim = df_item.loc[df_item['order_id'] == '083606af9191f3c3119ed90e616df1ca']
df_item_camocim.head()
# Out:
#                               order_id  order_item_id  \
# 3615  083606af9191f3c3119ed90e616df1ca              1
# 3616  083606af9191f3c3119ed90e616df1ca              2
#
#                             product_id                         seller_id  \
# 3615  afeeea6271148ee1bb15173b8187c431  53243585a1d6dc2643021fd1853d8905
# 3616  afeeea6271148ee1bb15173b8187c431  53243585a1d6dc2643021fd1853d8905
#
#       shipping_limit_date  price  freight_value
# 3615  2017-09-12 12:15:18  174.0          17.66
# 3616  2017-09-12 12:15:18  174.0          17.66

# %%
df_produt_camocim = df_produt.loc[df_produt['product_id'] == 'afeeea6271148ee1bb15173b8187c431']
df_produt_camocim
# Out:
#                             product_id product_category_name  \
# 8565  afeeea6271148ee1bb15173b8187c431             telefonia
#
#       product_name_lenght  product_description_lenght  product_photos_qty  \
# 8565                 52.0                      1885.0                 1.0
#
#       product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 8565             450.0               17.0                3.0              11.0

# %%
df_pe.head()
# Out:
#    index                       customer_id                customer_unique_id  \
# 0    110  b80adce6a72fc096b80a540312a24a95  8728c766c84eeda24b3e54fe6e632051
# 1    191  2abea2bf3e5611f7a96f8d24f21a7198  ed62ab8aab76f4d4efc4344ba5ef3a6d
# 2    203  314ec9cbe156ddd9cdaa1a9bf021e00e  691d75928efd2c5dd34b678f19783c28
# 3    260  09f548315be5f30a9610b83ad933aaf1  c1c2fffe3d49911803df2e157bee7aa0
# 4    417  a9434e011c74b3cfe8649aafc303c441  637c2caca17c2bf9fe41e50a6fcec9ed
#
#    customer_zip_code_prefix            customer_city customer_state
# 0                     53437                 paulista             PE
# 1                     52070                   recife             PE
# 2                     54430  jaboatao dos guararapes             PE
# 3                     55700                 limoeiro             PE
# 4                     55525                   cortes             PE

# %%
df_pe.shape
# Out:
# (1652, 6)

# %%
df_pe.columns
# Out:
# Index(['index', 'customer_id', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state'],
#       dtype='object')

# %%
df_pe['customer_city'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                          paulista
# 1                            recife
# 2           jaboatao dos guararapes
# 3                          limoeiro
# 4                            cortes
# 5                            recife
# 6                         salgueiro
# 7                            recife
# 8          sao jose da coroa grande
# 9                            recife
# 10                        petrolina
# 11                           recife
# 12                      rio formoso
# 13          jaboatao dos guararapes
# 14                          gravata
# 15                           olinda
# 16         sao jose da coroa grande
# 17                        petrolina
# 18          jaboatao dos guararapes
# 19                         limoeiro
# 20                           recife
# 21                        petrolina
# 22                           recife
# 23                           recife
# 24                          caruaru
# ...
